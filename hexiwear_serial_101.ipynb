# %%
import serial
import time
import sys
import glob
from tkinter import *
import win32com

# %%
s = serial.Serial('COM11',9600)

# %%
result = s.is_open
print(result)
# Out:
# True

# %%
s

# %%
s.write('s'.encode())
read = s.readline()
print(read)

# %%
#s.write('s'.encode())
while True:
    read = s.readline()
    print(read)
    read = read.decode()
    #time.sleep(1)
    if(read[0] == 'e'):
        print('out')
        break

# %%
print(b'2')
print('s'.encode())

# %%
result_decode = read.decode()
print(read, type(read))
print(result_decode, type(result_decode))

# %%
def serial_ports():
    """ Lists serial port names

        :raises EnvironmentError:
            On unsupported or unknown platforms
        :returns:
            A list of the serial ports available on the system
    """
    if sys.platform.startswith('win'):
        ports = ['COM%s' % (i + 1) for i in range(256)]
    elif sys.platform.startswith('linux') or sys.platform.startswith('cygwin'):
        # this excludes your current terminal "/dev/tty"
        ports = glob.glob('/dev/tty[A-Za-z]*')
    elif sys.platform.startswith('darwin'):
        ports = glob.glob('/dev/tty.*')
    else:
        raise EnvironmentError('Unsupported platform')

    result = []
    for port in ports:
        try:
            s = serial.Serial(port)
            s.close()
            result.append(port)
        except (OSError, serial.SerialException):
            pass
    return result

# %%
port_list = serial_ports()
print(port_list, type(port_list))
# Out:
# ['COM1'] <class 'list'>

# %%
result_close = s.close()
print(result_close)
# Out:
# None

# %%
root = Tk()
button_1 = Button(root, text="print my name")
button_1.bind("<Button-1>",serial_ports)
button_1.pack()
# label_1 = Label(root, text = "Serial")
# label_2 = Label(root, text = "Serial2")
# entry_1 = Entry(root)
# label_1.grid(row=0)

# entry_1.grid(row=0, column=1)
root.mainloop()

# %%
print(read,type(read),read.decode(),type(read.decode()))

# %%
rr = read.decode()
rr[0]

# %%
for i in range(1, 260):
    for j in range(1, 6):
        print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 1 4
# 1 5
# 2 1
# 2 2
# 2 3
# 2 4
# 2 5
# 3 1
# 3 2
# 3 3
# 3 4
# 3 5
# 4 1
# 4 2
# 4 3
# 4 4
# 4 5
# 5 1
# 5 2
# 5 3
# 5 4
# 5 5
# 6 1
# 6 2
# 6 3
# 6 4
# 6 5
# 7 1
# 7 2
# 7 3
# 7 4
# 7 5
# 8 1
# 8 2
# 8 3
# 8 4
# 8 5
# 9 1
# 9 2
# 9 3
# 9 4
# 9 5
# 10 1
# 10 2
# 10 3
# 10 4
# 10 5
# 11 1
# 11 2
# 11 3
# 11 4
# 11 5
# 12 1
# 12 2
# 12 3
# 12 4
# 12 5
# 13 1
# 13 2
# 13 3
# 13 4
# 13 5
# 14 1
# 14 2
# 14 3
# 14 4
# 14 5
# 15 1
# 15 2
# 15 3
# 15 4
# 15 5
# 16 1
# 16 2
# 16 3
# 16 4
# 16 5
# 17 1
# 17 2
# 17 3
# 17 4
# 17 5
# 18 1
# 18 2
# 18 3
# 18 4
# 18 5
# 19 1
# 19 2
# 19 3
# 19 4
# 19 5
# 20 1
# 20 2
# 20 3
# 20 4
# 20 5
# 21 1
# 21 2
# 21 3
# 21 4
# 21 5
# 22 1
# 22 2
# 22 3
# 22 4
# 22 5
# 23 1
# 23 2
# 23 3
# 23 4
# 23 5
# 24 1
# 24 2
# 24 3
# 24 4
# 24 5
# 25 1
# 25 2
# 25 3
# 25 4
# 25 5
# 26 1
# 26 2
# 26 3
# 26 4
# 26 5
# 27 1
# 27 2
# 27 3
# 27 4
# 27 5
# 28 1
# 28 2
# 28 3
# 28 4
# 28 5
# 29 1
# 29 2
# 29 3
# 29 4
# 29 5
# 30 1
# 30 2
# 30 3
# 30 4
# ...
